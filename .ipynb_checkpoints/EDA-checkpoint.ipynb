# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Sarah\Documents\Ironhack-DAFT-Project7-ML-Netflix\imdb_processed_clean.csv")

# %%
data
# Out:
#       year            kind  rating      vote    runtime       genre1  \
# 0     2003  tv mini series     7.7     474.0  50.000000  Documentary
# 1     1994     video movie     8.1      18.0  83.000000       Family
# 2     1992           movie     5.5      93.0  96.828211       Action
# 3     2004           movie     5.3   13432.0  60.000000  Documentary
# 4     1991           movie     4.5    2177.0  96.000000       Comedy
# ...    ...             ...     ...       ...        ...          ...
# 8063  1969           movie     3.9    4384.0  96.828211    Adventure
# 8064  2005         episode     6.4      44.0  96.083333  Documentary
# 8065  2001        tv movie     4.9    2376.0  96.359350       Sci-Fi
# 8066  2003           movie     6.3    6501.0  96.828211        Drama
# 8067  1987           movie     7.8  386850.0  96.828211       Action
#
#           genre2       country1  country2 language1 language2  \
# 0      Animation  United States      None   English      None
# 1           None  United States      None   English      None
# 2         Sci-Fi          Japan      None  Japanese      None
# 3         Comedy  United States      None   English    German
# 4         Horror  United States      None   English      None
# ...          ...            ...       ...       ...       ...
# 8063      Family          Japan      None  Japanese      None
# 8064   Biography        Unknown      None   English   Spanish
# 8065    Thriller  United States      None   English      None
# 8066       Music  United States   Germany   English      None
# 8067   Adventure  United States    Mexico   English   Spanish
#
#                       cast1               cast2          director1  \
# 0          Christian Slater       Scott Sampson            Unknown
# 1               Paula Abdul      Aurorah Allain      Steve Purcell
# 2              Kai Shishido   Etsushi Takahashi  Yasuhiro Horiuchi
# 3             Marlee Matlin      Elaine Hendrix      William Arntz
# 4             Brick Bronsky           Lisa Gaye        Eric Louzil
# ...                     ...                 ...                ...
# 8063        Tomonori Yazaki      Hideyo Amamoto       Ishirô Honda
# 8064            Rena Baskin   Fulgencio Batista      Adriana Bosch
# 8065            David Keith    Stephanie Niznik          Matt Codd
# 8066          Neve Campbell    Malcolm McDowell      Robert Altman
# 8067  Arnold Schwarzenegger       Carl Weathers     John McTiernan
#
#                 director2           composer1 composer2            writer1  \
# 0                    None             Unknown      None        Mike Carrol
# 1                    None             Unknown      None            Unknown
# 2                    None         Carole King      None     Kazumasa Hirai
# 3            Betsy Chasse  Christopher Franke      None      William Arntz
# 4                    None         Bob Mithoff      None      Lloyd Kaufman
# ...                   ...                 ...       ...                ...
# 8063           Jun Fukuda      Kunio Miyauchi      None  Shinichi Sekizawa
# 8064   M Pink Christofalo        Mason Daring      None      Adriana Bosch
# 8065                 None      Richard McHugh      None   Jonathan Raymond
# 8066                 None      Van Dyke Parks      None      Neve Campbell
# 8067                 None      Alan Silvestri      None         Jim Thomas
#
#                 writer2
# 0          Mike Carroll
# 1                  None
# 2           Jirô Kuwata
# 3          Betsy Chasse
# 4           Carl Morano
# ...                 ...
# 8063               None
# 8064               None
# 8065   Jonathan Raymond
# 8066     Barbara Turner
# 8067        John Thomas
#
# [8068 rows x 19 columns]

# %%
countries = data.groupby('country1', as_index=False)['genre1'].count()

# %%
countries.sort_values(by='genre1', inplace=True, ascending=False)
countries['country1'] = np.where(countries['genre1']<=5, "grouped countries(5)",countries['country1'])

# %%
countries.sort_values(by='genre1',ascending=False, inplace=True)

# %%
fig = plt.figure(figsize=(18,10))
plot1 = fig.add_subplot(111)
plot1.bar(x=countries['country1'], height=countries['genre1'])
plt.title('Total number of movies per country',{'fontsize': 20})

plt.xticks(rotation=45,fontsize=14)
plt.grid(True)
plt.show()

# %%
years = data.groupby('year', as_index=False)['genre1'].count()

# %%
years.sort_values(by='genre1', inplace=True, ascending=False)

# %%
fig = plt.figure(figsize=(18,10))
plot1 = fig.add_subplot(111)
plot1.bar(x=years['year'], height=years['genre1'])
plt.title('Total number of movies per year',{'fontsize': 20})

plt.xticks(rotation=45,fontsize=14)
plt.grid(True)
plt.show()

# %%
country_genre = data.groupby('country1', as_index=False)['genre1'].max()

# %%
country = data.groupby(['genre1','country1'],as_index=False)['kind'].count()

# %%
countries = country['country1'].unique()

# %%
df = pd.DataFrame(columns=['genre1', 'country1', 'kind'])
for i in countries:
    a =country[country['country1']==i]
    a = a[a['kind']==a.kind.max()]
    df = df.append(a)

# %%
df.sort_values(by='kind', ascending=False, inplace=True)

# %%
g=sns.catplot(x='country1', y='kind', hue="genre1", data=df, s=20)
plt.xticks(rotation=45)
plt.title('Most popular genre per country',{'fontsize': 20})
g.fig.set_size_inches(23,15)

# %%
year = data.groupby(['genre1','year'],as_index=False)['kind'].count()
year
# Out:
#       genre1  year  kind
# 0     Action  1914     1
# 1     Action  1926     1
# 2     Action  1928     1
# 3     Action  1931     1
# 4     Action  1936     1
# ..       ...   ...   ...
# 825  Western  1996     1
# 826  Western  1999     1
# 827  Western  2002     1
# 828  Western  2003     1
# 829  Western  2004     1
#
# [830 rows x 3 columns]

# %%
years = year['year'].unique()
years
# Out:
# array([1914, 1926, 1928, 1931, 1936, 1938, 1941, 1944, 1945, 1948, 1949,
#        1950, 1951, 1952, 1954, 1955, 1956, 1957, 1958, 1960, 1961, 1962,
#        1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973,
#        1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984,
#        1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 1924,
#        1929, 1930, 1940, 1953, 1959, 1942, 1947, 1927, 1933, 1937, 1918,
#        1923, 1925, 1932, 1934, 1939, 1943, 1935, 1946, 1922, 1916, 1919],
#       dtype=int64)

# %%
df2 = pd.DataFrame(columns=['genre1', 'kind'])
for i in years:
    a =year[year['year']==i]
    a = a[a['kind']==a.kind.max()]
    df2 = df2.append(a)

# %%
df2.sort_values(by='year', inplace=True)
df2
# Out:
#           genre1 kind    year
# 0         Action    1  1914.0
# 425        Drama    1  1916.0
# 222       Comedy    3  1918.0
# 426        Drama    1  1919.0
# 368  Documentary    2  1922.0
# 223       Comedy    1  1923.0
# 65     Adventure    1  1924.0
# 224       Comedy    1  1924.0
# 427        Drama    1  1925.0
# 225       Comedy    1  1925.0
# 300        Crime    1  1925.0
# 369  Documentary    1  1925.0
# 66     Adventure    2  1926.0
# 429        Drama    2  1927.0
# 170    Biography    2  1927.0
# 430        Drama    2  1928.0
# 739        Short    1  1929.0
# 431        Drama    1  1929.0
# 67     Adventure    1  1929.0
# 227       Comedy    3  1930.0
# 302        Crime    2  1931.0
# 432        Drama    3  1932.0
# 304        Crime    1  1933.0
# 371  Documentary    1  1933.0
# 172    Biography    1  1933.0
# 230       Comedy    1  1933.0
# 231       Comedy    2  1934.0
# 433        Drama    2  1934.0
# 305        Crime    1  1935.0
# 373  Documentary    1  1935.0
# 434        Drama    2  1936.0
# 503       Family    2  1936.0
# 233       Comedy    2  1937.0
# 5         Action    2  1938.0
# 234       Comedy    2  1938.0
# 235       Comedy    3  1939.0
# 236       Comedy    2  1940.0
# 69     Adventure    2  1940.0
# 308        Crime    1  1941.0
# 6         Action    1  1941.0
# 438        Drama    1  1941.0
# 439        Drama    4  1942.0
# 238       Comedy    2  1943.0
# 440        Drama    2  1943.0
# 677      Mystery    3  1944.0
# 442        Drama    6  1945.0
# 443        Drama    6  1946.0
# 313        Crime    5  1947.0
# 445        Drama    3  1948.0
# 10        Action    3  1949.0
# 243       Comedy    3  1949.0
# 315        Crime    3  1949.0
# 316        Crime    4  1950.0
# 448        Drama    8  1951.0
# 449        Drama    6  1952.0
# 247       Comedy    5  1953.0
# 73     Adventure    3  1954.0
# 249       Comedy    6  1955.0
# 453        Drama    4  1956.0
# 454        Drama   15  1957.0
# 455        Drama    8  1958.0
# 456        Drama   34  1959.0
# 457        Drama   13  1960.0
# 458        Drama   10  1961.0
# 459        Drama   10  1962.0
# 460        Drama   10  1963.0
# 461        Drama   13  1964.0
# 462        Drama   10  1965.0
# 25        Action   12  1966.0
# 261       Comedy   13  1967.0
# 262       Comedy   12  1968.0
# 466        Drama   13  1969.0
# 467        Drama   12  1970.0
# 468        Drama   13  1971.0
# 31        Action   19  1972.0
# 32        Action   19  1973.0
# 471        Drama   29  1974.0
# 34        Action   10  1975.0
# 473        Drama   16  1976.0
# 474        Drama   13  1977.0
# 37        Action   14  1978.0
# 476        Drama   15  1979.0
# 38        Action   15  1979.0
# 39        Action   19  1980.0
# 595       Horror   18  1981.0
# 41        Action   13  1982.0
# 42        Action   16  1983.0
# 43        Action   13  1984.0
# 278       Comedy   13  1984.0
# 279       Comedy   17  1985.0
# 280       Comedy   21  1986.0
# 46        Action   33  1987.0
# 282       Comedy   28  1988.0
# 283       Comedy   22  1989.0
# 49        Action   27  1990.0
# 285       Comedy   27  1991.0
# 488        Drama   27  1991.0
# 489        Drama   29  1992.0
# 286       Comedy   29  1992.0
# 52        Action   38  1993.0
# 53        Action   42  1994.0
# 492        Drama   40  1995.0
# 290       Comedy   63  1996.0
# 416  Documentary   63  1997.0
# 292       Comedy   67  1998.0
# 418  Documentary   86  1999.0
# 497        Drama  108  2000.0
# 498        Drama  113  2001.0
# 421  Documentary  138  2002.0
# 422  Documentary  149  2003.0
# 423  Documentary  176  2004.0
# 424  Documentary   69  2005.0

# %%
g=sns.catplot(x='year', y='kind', hue="genre1", data=df2, s=20)
plt.xticks(rotation=45)
plt.title('Most popular genre per year',{'fontsize': 20})
g.fig.set_size_inches(23,15)
